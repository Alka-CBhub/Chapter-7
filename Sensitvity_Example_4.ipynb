# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plot_utils import set_plot_style, set_spines_black
from sensitivity_plot_utils import plot_sensitivity_bars
set_plot_style(dpi=100, grid=False)

# %%
file_path1 = "Sensivity_Results/Ex4_Ori_df_CDK1.csv"
file_path2 = "Sensivity_Results/Ex4_Rational_x_df_CDK1.csv"
file_path3 = "Sensivity_Results/Ex4_Rational_x_s_df_CDK1.csv"

# %%
df1 = pd.read_csv(file_path1, index_col=0)
df1_sorted = df1.sort_values('Scaled')
df2 = pd.read_csv(file_path2, index_col=0)
df2_sorted = df2.sort_values('Scaled')
df3 = pd.read_csv(file_path3, index_col=0)
df3_sorted = df3.sort_values('Scaled')

# %%
dfs_CDK1 = [df1_sorted, df2_sorted, df3_sorted]

# %%
# Sensivity Bar
plot_sensitivity_bars(
    dfs=dfs_CDK1,
    group_labels=["CDK1", "CDK1 Rational", "CDK1 SINDy"]
)

# %%
file_path4 = "Sensivity_Results/Ex4_Ori_df_APC.csv"
file_path5 = "Sensivity_Results/Ex4_Rational_x_df_APC.csv"
file_path6 = "Sensivity_Results/Ex4_Rational_x_s_df_APC.csv"

# %%
df4 = pd.read_csv(file_path4, index_col=0)
df4_sorted = df4.sort_values('Scaled')
df5 = pd.read_csv(file_path5, index_col=0)
df5_sorted = df5.sort_values('Scaled')
df6 = pd.read_csv(file_path6, index_col=0)
df6_sorted = df6.sort_values('Scaled')

# %%
dfs_APC = [df4_sorted, df5_sorted, df6_sorted]

# %%
# Sensivity Bar
plot_sensitivity_bars(
    dfs=dfs_APC,
    group_labels=["APC", "APC Rational", "APC SINDy"]
)

# %%
file_path7 = "Sensivity_Results/Ex4_Ori_df_Plk1.csv"
file_path8 = "Sensivity_Results/Ex4_Rational_x_df_Plk1.csv"
file_path9 = "Sensivity_Results/Ex4_Rational_x_s_df_Plk1.csv"

# %%
df7 = pd.read_csv(file_path7, index_col=0)
df7_sorted = df7.sort_values('Scaled')
df8 = pd.read_csv(file_path8, index_col=0)
df8_sorted = df8.sort_values('Scaled')
df9 = pd.read_csv(file_path9, index_col=0)
df9_sorted = df9.sort_values('Scaled')

# %%
dfs_Plk1 = [df7_sorted, df8_sorted, df9_sorted]

# %%
# Sensivity Bar
plot_sensitivity_bars(
    dfs=dfs_Plk1,
    group_labels=["Plk1", "Plk1 Rational", "Plk1 SINDy"]
)

# %%
#*****************************************************************************************************************************************************
#                                                                   END
#
#*****************************************************************************************************************************************************
