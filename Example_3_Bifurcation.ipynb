# %%
import os
# print("Current directory:", os.getcwd())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from plot_utils import set_plot_style, set_spines_black

# %%
# Load the data (.dat FILE))
x = np.loadtxt('DAT_Files/Example_3.dat')
df = pd.DataFrame(x)
print(df.head(5))
# Out:
#          0         1         2    3    4    5
# 0  1.50000  0.761279  0.761279  2.0  1.0  0.0
# 1  1.49803  0.760927  0.760927  1.0  1.0  0.0
# 2  1.49606  0.760576  0.760576  1.0  1.0  0.0
# 3  1.49409  0.760224  0.760224  1.0  1.0  0.0
# 4  1.49213  0.759872  0.759872  1.0  1.0  0.0

# %%
print(df.nunique())
# Out:
# 0    2551
# 1    2576
# 2    2536
# 3       4
# 4       2
# 5       1
# dtype: int64

# %%
# Columns
S = x[:, 0] # Signal/ Parameter
R1 = x[:, 1]
R2 = x[:, 2]
regime = x[:, 3].astype(int)

# %%
# Find steady state indices for each regime (and positive R1)
ss1 = np.unique(np.where((regime == 1) & (R1 > 0))[0])
ss2 = np.unique(np.where((regime == 2) & (R1 > 0))[0]) 
ss3 = np.unique(np.where((regime == 3) & (R1 > 0))[0])
ss4 = np.unique(np.where((regime == 4) & (R1 > 0))[0])

# %%
# Identify Hopf parameter values from AUTO
hb_params = [0.433286] 
hb_indices = []
tol = 1e-6
for val in hb_params:
    diffs = np.abs(S - val)
    idx0  = np.argmin(diffs)
    if diffs[idx0] > tol:
        print(f"Closest match to {val} is {S[idx0]} (diff={diffs[idx0]:.2e})")
    else:
        print(f"Found Hopf at S[{idx0}] = {S[idx0]}")
    print(f"regime={regime[idx0]}, R1={R1[idx0]}")
    hb_indices.append(idx0)

print("Final Hopf indices:", hb_indices)
# Out:
# Found Hopf at S[566] = 0.433286
# regime=2, R1=0.492234
# Final Hopf indices: [np.int64(566)]

# %%
hopf_idx = 566
x_hb, y_hb = S[hopf_idx], R1[hopf_idx]

# %%
# Initialize Figure
set_plot_style(dpi=100)
plt.figure(figsize=(7, 5))

# Define masks explicitly
red_mask = S[ss1] >= x_hb
black_mask = S[ss2] <= x_hb

# Regime 1:
plt.plot(S[ss1][red_mask], R1[ss1][red_mask], 'r-', linewidth=3, label='SS')
# Regime 2:
plt.plot(S[ss2][black_mask], R1[ss2][black_mask], 'k-', linewidth=3, label='USS')

# Regime 3: 
neon_lime = '#00FF00'  
plt.plot(S[ss3], R1[ss3], '-', color=neon_lime, linewidth=3, label='SLC')
plt.plot(S[ss3], R2[ss3], '-', color=neon_lime, linewidth=3)

# Regime 4: 
plt.plot(S[ss4][2:], R1[ss4][2:],  'b-', linewidth=3.5)
plt.plot(S[ss4][2:], R2[ss4][2:],  'b-', linewidth=3.5)


# Mark the Hopf point 
plt.plot(x_hb, y_hb,
         marker='o', linestyle='',
         markeredgecolor='b', markerfacecolor='white',
         markersize=12, mew=2)

plt.text(
    x_hb+0.01, y_hb-0.02,
    r'$\leftarrow\,HB$',
    fontsize=16,
    fontweight='bold'
)
# Grid, labels, and styling
plt.grid(True, which='both', ls='--', lw=0.5)
plt.title('Codimension-one Bifurcation Diagram')
plt.xlabel(r'$\alpha_1$')
plt.ylabel(r'$CDK1*$')

# Thicken and color the axis spines
ax = plt.gca()
set_spines_black(ax) 

plt.legend(loc='lower right', fontsize=12, frameon=False)
plt.savefig("Plots_3/CDK1_APC_PF_Bifurcation.pdf", bbox_inches="tight")
plt.show()

# %%
##############################################################################################################################################
