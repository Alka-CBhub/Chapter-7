# %%
# Import necessary Libraries
import os
print("Current directory:", os.getcwd())
# Out:
# Current directory: /home/alka23224/7_Cell_Cycle_Modelling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from plot_utils import set_plot_style, set_spines_black

# %%
# Load the data (.dat FILE))
x = np.loadtxt("DAT_Files/Example_1.dat")
df = pd.DataFrame(x)
print(df.head(5))
# Out:
#          0         1         2    3    4    5
# 0  1.50000  0.744956  0.744956  2.0  1.0  0.0
# 1  1.49803  0.744602  0.744602  1.0  1.0  0.0
# 2  1.49606  0.744249  0.744249  1.0  1.0  0.0
# 3  1.49409  0.743895  0.743895  1.0  1.0  0.0
# 4  1.49213  0.743541  0.743541  1.0  1.0  0.0

# %%
print(df.nunique())
# Out:
# 0    1000
# 1    1000
# 2    1000
# 3       2
# 4       1
# 5       1
# dtype: int64

# %%
# Identify the indices where the 4th column equals 2 ## untable Branch
ss1 = np.where(x[:, 3] == 2)[0]
# print("All row indices for unstable branch:\n",ss1)

# %%
print('Index where unstable branch starts:', ss1[1])
print('Index where unstable branch ends:', ss1[-1])
# Out:
# Index where unstable branch starts: 409
# Index where unstable branch ends: 554

# %%
# coordinates of saddle‐node points
x_sn1, y_sn1 = x[ss1[-1], 0], x[ss1[-1], 1]
x_sn2, y_sn2 = x[ss1[1], 0], x[ss1[1], 1]
print(f"Saddle-node 1: x={x_sn1:.4f}, y={y_sn1:.4f}")
print(f"Saddle-node 2: x={x_sn2:.4f}, y={y_sn2:.4f}")
# Out:
# Saddle-node 1: x=0.9544, y=0.3755
# Saddle-node 2: x=0.7232, y=0.5341

# %%
# Initialize Figure
set_plot_style(dpi=100)
plt.figure(figsize=(7, 5))

# Segment 1: Stable branch
plt.plot(
    x[:ss1[1] + 1, 0],
    x[:ss1[1] + 1, 1],
    color='r',
    linewidth=3,
    label='SS'
)

# Segment 2: Unstable branch 
plt.plot(
    x[ss1[1]:ss1[-1] + 1, 0],
    x[ss1[1]:ss1[-1] + 1, 1],
    linestyle='-',
    color='k',
    linewidth=3,
    label='USS'
)

# Segment 3: Stable branch 
plt.plot(
    x[ss1[-1]:, 0],
    x[ss1[-1]:, 1],
    color='r',
    linewidth=3
)

plt.plot(x_sn1, y_sn1, 'o', color='k', markersize=8)
plt.plot(x_sn2, y_sn2, 'o', color='k', markersize=8)
# Annotate the saddle-node points
plt.text(
    x_sn1-0.02, y_sn1,
    r'$SN_1 \rightarrow$',
    fontsize=16,
    ha='right', va='center'
)

plt.text(
    x_sn2+0.01, y_sn2-0.01,
    r'$\leftarrow\,SN_2$',
    fontsize=16,

)

# Grid, labels, and styling
plt.grid(True, which='both', ls='--', lw=0.5)
plt.title('Codimension-one Bifurcation Diagram')
plt.xlabel(r'$\alpha_1$')
plt.ylabel(r'$CDK1^*$')

# Make spines black
ax = plt.gca()
set_spines_black(ax)

# Add legend
plt.legend(fontsize=13, loc='best', frameon=False)

# Save and show
plt.savefig("Plots_1/CDK1_Bifurcation.pdf", bbox_inches="tight")
plt.show()

# %%
#******************************************************* END *********************************************************************************
